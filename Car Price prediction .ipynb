# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
dataset=pd.read_csv("CarPrice.csv")

# %%
dataset.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
dataset.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
dataset.shape
# Out:
# (205, 26)

# %%
dataset.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %% [markdown]
#  <h1><center>Data Cleaning</center></h1>

# %% [markdown]
# ### Checking for Missing values

# %%
dataset.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
#  No Null vales is present

# %% [markdown]
# ### Checking for Duplicates

# %%
dataset[dataset.duplicated()]
# Out:
# Empty DataFrame
# Columns: [car_ID, symboling, CarName, fueltype, aspiration, doornumber, carbody, drivewheel, enginelocation, wheelbase, carlength, carwidth, carheight, curbweight, enginetype, cylindernumber, enginesize, fuelsystem, boreratio, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# No Duplicate rows is present

# %%
dataset.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %% [markdown]
# ###### Here we will check unique values of CarName column

# %%
dataset['CarName'] = dataset['CarName'].str.split(' ',expand=True)[0]          # Onlye take the First name of the model
dataset['CarName'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %%
dataset['CarName'] = dataset['CarName'].replace({'maxda': 'mazda', 'Nissan': 'nissan', 'porcshce': 'porsche', 'toyouta': 'toyota', 
                            'vokswagen': 'volkswagen', 'vw': 'volkswagen'})

# %%
dataset['CarName'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'nissan', 'peugeot', 'plymouth', 'porsche', 'renault', 'saab',
#        'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
dataset.drop("car_ID" , axis=1 , inplace=True)   # As car_ID column is of no use

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   CarName           205 non-null    object
#  2   fueltype          205 non-null    object
#  3   aspiration        205 non-null    object
#  4   doornumber        205 non-null    object
#  5   carbody           205 non-null    object
#  6   drivewheel        205 non-null    object
#  7   enginelocation    205 non-null    object
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    object
#  14  cylindernumber    205 non-null    object
#  15  enginesize        205 non-null    int64
# ...

# %%
dataset.dtypes.value_counts()
# Out:
# object     10
# float64     8
# int64       7
# dtype: int64

# %% [markdown]
# The dataset has 10 categorical features and 15 Numerical features

# %% [markdown]
# #### Splitting the data into cateorical and Numerical features dataset

# %%
col_categorical = dataset.select_dtypes(include=['object']).columns
col_numerical = dataset.select_dtypes(exclude=['object']).columns
dataset[col_categorical]=dataset[col_categorical].astype(str)
df_cat = dataset[col_categorical]
df_num = dataset[col_numerical]

# %%
df_cat.head()
# Out:
#        CarName fueltype aspiration doornumber      carbody drivewheel  \
# 0  alfa-romero      gas        std        two  convertible        rwd
# 1  alfa-romero      gas        std        two  convertible        rwd
# 2  alfa-romero      gas        std        two    hatchback        rwd
# 3         audi      gas        std       four        sedan        fwd
# 4         audi      gas        std       four        sedan        4wd
#
#   enginelocation enginetype cylindernumber fuelsystem
# 0          front       dohc           four       mpfi
# 1          front       dohc           four       mpfi
# 2          front       ohcv            six       mpfi
# 3          front        ohc           four       mpfi
# 4          front        ohc           five       mpfi

# %%
df_num.head()
# Out:
#    symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0          3       88.6      168.8      64.1       48.8        2548
# 1          3       88.6      168.8      64.1       48.8        2548
# 2          1       94.5      171.2      65.5       52.4        2823
# 3          2       99.8      176.6      66.2       54.3        2337
# 4          2       99.4      176.6      66.4       54.3        2824
#
#    enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# 0         130       3.47    2.68               9.0         111     5000
# 1         130       3.47    2.68               9.0         111     5000
# 2         152       2.68    3.47               9.0         154     5000
# 3         109       3.19    3.40              10.0         102     5500
# 4         136       3.19    3.40               8.0         115     5500
#
#    citympg  highwaympg    price
# 0       21          27  13495.0
# 1       21          27  16500.0
# ...

# %%
dataset.shape
# Out:
# (205, 25)

# %% [markdown]
# ### Result

# %% [markdown]
#  We can understand that we have a dataset with 205 observations with 0 Missing Values, 25 columns : in which 24 features and 1 target (Price). We also have 15 numerical features and 10 catagorical ones that we need to encode

# %% [markdown]
# <h1><center>Data Visualization</center></h1>

# %% [markdown]
# ###  Checking for the distributions

# %% [markdown]
# #### Distribution of Car Body type

# %%
dataset['carbody'].value_counts()
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64

# %%
rt=dataset['carbody'].value_counts().plot.pie(stacked=True,autopct="%.2f", colormap ='viridis' )
rt.title.set_text('Distribution of carbody')
#plt.xlabel("Name of Cars body",fontweight = 'bold')
#plt.ylabel("Count of Cars",fontweight = 'bold')

# %% [markdown]
#  sedan is the most popular car body type

# %% [markdown]
# #### Distribution of Car Price

# %%
sns.histplot(dataset["price"], kde=True ,color='green', edgecolor='b')
plt.title('Distribution of Car Price')
# Out:
# Text(0.5, 1.0, 'Distribution of Car Price')

# %% [markdown]
#  The distribution is not symmetric. Most of the car has price less than 20000$

# %% [markdown]
# #### Distribution of Car Names

# %%
cn=dataset['CarName'].value_counts().plot(kind='bar', colormap = 'autumn')
cn.title.set_text('CarName')
plt.xlabel("Names of the Car",fontweight = 'bold')
plt.ylabel("Count of Cars",fontweight = 'bold')
# Out:
# Text(0, 0.5, 'Count of Cars')

# %% [markdown]
# Toyota is the most Favourite Car and mercury is the least favourite car

# %% [markdown]
# ## Visualizing Categorical features

# %%
fig, axes = plt.subplots(3,3 , figsize=(24,18))
axes = axes.flatten()
features = list(df_cat.columns)
features.remove("CarName")
for i in range(len(features)):
    sns.boxplot(x = features[i], y = 'price', data = dataset,ax=axes[i])

# %% [markdown]
# #### Key Points from this visualization

# %% [markdown]
# - In fueltype diesel is slightly expansive than gas.
# - hardtop and convertible are the most expensive carbody.
# - Engine ohvc has the highest price.
# - In aspiration turbo cars are more expensive.
# - Drivewheel rwd has the highest price.
# - The cars with front enginelocation are way cheaper than cars with rear enginelocation.
# - The price is almost similar for two and four doornumber.

# %% [markdown]
# ## Visualizing Numerical features

# %%
df_num.columns
# Out:
# Index(['symboling', 'wheelbase', 'carlength', 'carwidth', 'carheight',
#        'curbweight', 'enginesize', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
df_num.drop('symboling',axis=1,inplace=True)

# %%
df_num.corr()
# Out:
#                   wheelbase  carlength  carwidth  carheight  curbweight  \
# wheelbase          1.000000   0.874587  0.795144   0.589435    0.776386
# carlength          0.874587   1.000000  0.841118   0.491029    0.877728
# carwidth           0.795144   0.841118  1.000000   0.279210    0.867032
# carheight          0.589435   0.491029  0.279210   1.000000    0.295572
# curbweight         0.776386   0.877728  0.867032   0.295572    1.000000
# enginesize         0.569329   0.683360  0.735433   0.067149    0.850594
# boreratio          0.488750   0.606454  0.559150   0.171071    0.648480
# stroke             0.160959   0.129533  0.182942  -0.055307    0.168790
# compressionratio   0.249786   0.158414  0.181129   0.261214    0.151362
# horsepower         0.353294   0.552623  0.640732  -0.108802    0.750739
# peakrpm           -0.360469  -0.287242 -0.220012  -0.320411   -0.266243
# citympg           -0.470414  -0.670909 -0.642704  -0.048640   -0.757414
# ...

# %%
fig, axes = plt.subplots(5,3 , figsize=(24,18))
axes = axes.flatten()
features = df_num.columns[:-1]
for i in range(len(features)):
    sns.scatterplot(data=dataset, x="price",y=features[i],ax=axes[i],color='red')

# %% [markdown]
# #### From this we can say that :-
#     1) wheelbase , carlength , carwidth , curbweight , enginesize , boreratio , horsepower are in positive correlation with the price.
#     2) peakrpm , citympg , highwaympg are in negative correlation with the price.
#     3) No correlation between carheight , stroke , compressionratio.

# %% [markdown]
# ### Conclusion

# %% [markdown]
#  We can remove the columns which of no use for our analysis

# %%
final_data = dataset[['price','enginetype','fueltype', 'aspiration','carbody','cylindernumber', 'drivewheel','wheelbase','curbweight', 'enginesize', 'boreratio','horsepower', 'citympg','highwaympg', 'carlength','carwidth']]

# %% [markdown]
# <h1><center> Data Preprocessing </center></h1>

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   price           205 non-null    float64
#  1   enginetype      205 non-null    object
#  2   fueltype        205 non-null    object
#  3   aspiration      205 non-null    object
#  4   carbody         205 non-null    object
#  5   cylindernumber  205 non-null    object
#  6   drivewheel      205 non-null    object
#  7   wheelbase       205 non-null    float64
#  8   curbweight      205 non-null    int64
#  9   enginesize      205 non-null    int64
#  10  boreratio       205 non-null    float64
#  11  horsepower      205 non-null    int64
#  12  citympg         205 non-null    int64
#  13  highwaympg      205 non-null    int64
#  14  carlength       205 non-null    float64
#  15  carwidth        205 non-null    float64
# dtypes: float64(5), int64(5), object(6)
# ...

# %%
final_data.dtypes.value_counts()
# Out:
# object     6
# float64    5
# int64      5
# dtype: int64

# %% [markdown]
# we have 6 catagorical features to deal with for that we will use Encoding

# %% [markdown]
# ### Encoding

# %%
from sklearn.preprocessing import LabelEncoder
categorical=['enginetype','fueltype','aspiration','carbody','cylindernumber','drivewheel']
for x in categorical:
    encoder = LabelEncoder()
    final_data[x]= encoder.fit_transform(final_data[x])
final_data.head()
# Out:
#      price  enginetype  fueltype  aspiration  carbody  cylindernumber  \
# 0  13495.0           0         1           0        0               2
# 1  16500.0           0         1           0        0               2
# 2  16500.0           5         1           0        2               3
# 3  13950.0           3         1           0        3               2
# 4  17450.0           3         1           0        3               1
#
#    drivewheel  wheelbase  curbweight  enginesize  boreratio  horsepower  \
# 0           2       88.6        2548         130       3.47         111
# 1           2       88.6        2548         130       3.47         111
# 2           2       94.5        2823         152       2.68         154
# 3           1       99.8        2337         109       3.19         102
# 4           0       99.4        2824         136       3.19         115
#
#    citympg  highwaympg  carlength  carwidth
# 0       21          27      168.8      64.1
# ...

# %% [markdown]
# ### Splitting the Data

# %%
train_data = final_data.drop('price',axis=1)
target_data = final_data['price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_data, target_data, test_size=0.2, random_state=50)

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train= scaler.fit_transform(X_train)
X_test= scaler.transform(X_test)

# %% [markdown]
# ###  Building Models

# %% [markdown]
# #### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

model = LinearRegression()
model.fit(X_train,y_train)
preds=model.predict(X_test)
print(r2_score(preds,y_test))
# Out:
# 0.7882651712588188

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(X_train,y_train)
preds=model.predict(X_test)
print(r2_score(preds,y_test))
# Out:
# 0.8926314315936479

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(X_train,y_train)
preds=model.predict(X_test)
print(r2_score(preds,y_test))
# Out:
# 0.9117952129096165

# %% [markdown]
# ### KNeighbours Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor
model = KNeighborsRegressor(n_neighbors=2)
model.fit(X_train,y_train)
preds=model.predict(X_test)
print(r2_score(preds,y_test))
# Out:
# 0.8985605308763447

# %% [markdown]
# # Conclusion

# %% [markdown]
# we finally got an r2 score of 91% using Random Forest
